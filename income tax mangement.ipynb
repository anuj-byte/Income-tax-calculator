# %%
age=int(input("Enter the age : "))
income_1=int(input("Enter first income source : "))
income_2=int(input("Enter second income source : "))
income_3=int(input("Enter third income source : "))
spending=int(input("Enter total spending : "))
rent=int(input("Enter total Rent paid : "))
income=(income_1+income_2+income_3) - (spending+rent)
if age <=60:
    if income <=250000:
        tax1=0
    elif income >=250001 and income <=500000:
        a=income-250000
        b= (5/100)*a
        tax1 =b-b
    elif income >=500001 and income <=750000:
        a=income-500000
        b=(10/100)*a
        tax1 = b+ (4/100)*b
    elif income >=750001 and income <=1000000:
        a=income-750000
        b=(15/100)*a
        tax1=b+(4/100)*b
    elif income >=1000001 and income <=1250000:
        a=income-1000000
        b=(20/100)*a
        tax1=b+(4/100)*b
    elif income >=1250001 and income <=1500000:
        a=income - 1250000
        b =(25/100)*a
        tax1 = b+(4/100)*b 
    elif income >=1500001:
        a=income - 1500000
        b=(30/100)*a
        tax1 = b+(4/100)*b
    if age<=60:
        if income <=250000:
            tax2=0
        elif income >=250001 and income <=500000:
            a=income-250000
            b= (5/100)*a
            tax2 = b-b
        elif income >=500001 and income <=1000000:
            a=income-500000
            b=(20/100)*a
            tax2= b+(4/100)*b
        elif income >=1000001:
            a=income-1000000
            b=(30/100)*a
            tax2=b+(4/100)*b
    if tax1>tax2:
        print("old regime",tax2)
    else:
        print("new regime",tax1)
if age>=60 and age<=80:
       
    if income <=250000:
        tax1=0
    elif income >=250001 and income <=500000:
        a=income-250000
        b= (5/100)*a
        tax1 =b-b
    elif income >=500001 and income <=750000:
        a=income-500000
        b=(10/100)*a
        tax1 = b+ (4/100)*b
    elif income >=750001 and income <=1000000:
        a=income-750000
        b=(15/100)*a
        tax1=b+(4/100)*b
    elif income >=1000001 and income <=1250000:
        a=income-1000000
        b=(20/100)*a
        tax1=b+(4/100)*b
    elif income >=1250001 and income <=1500000:
        a=income - 1250000
        b =(25/100)*a
        tax1 = b+(4/100)*b 
    elif income >=1500001:
        a=income - 1500000
        b=(30/100)*a
        tax1 = b+(4/100)*b
    if income <=250000:            
        tax2=0
    elif income >=250001 and income <=300000:
        tax2 = 0
    elif income >=300001 and income <=500000:
        a=income-500000
        b=(5/100)*a
        tax2= b-b
    elif income >=500001 and income <=1000000:
        a=income-500000
        b=(20/100)*a
        tax2=b+(4/100)*b
    elif income >=1000001:
        a=income-1000000
        b=(30/100)*a
        tax2=b+(4/100)*b
    if tax1>tax2:
        print("old regime",tax2)
    else:
        print("new regime",tax1)
# Out:
# Enter the age : 23
